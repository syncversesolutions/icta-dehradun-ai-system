# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ============================================
# ENVIRONMENT INITIALIZATION
# ============================================

# %run /content/drive/MyDrive/project_cd/config/environment.py

# ============================================
# IMPORTS
# ============================================

import pandas as pd

from config.paths import PATHS

from system.state.state_manager import (
    StateManager
)

from system.prediction.risk_forecaster import (
    RiskForecaster
)

from system.prediction.trend_analyzer import (
    TrendAnalyzer
)

from system.ai.decision.decision_engine import (
    DecisionEngine
)

# ============================================
# LOAD STATE
# ============================================

state_manager = StateManager()

state = state_manager.load_state()

# ============================================
# LOAD KPI DATA
# ============================================

kpi_path = (

    PATHS["accommodation"]["kpi"] +
    "accommodation_kpi.csv"
)

df = pd.read_csv(kpi_path)

# ============================================
# GENERATE PREDICTIONS
# ============================================

forecaster = RiskForecaster(
    state
)

predictions = forecaster.run()

# ============================================
# ANALYZE TRENDS
# ============================================

trend_analyzer = TrendAnalyzer(df)

trends = trend_analyzer.analyze()

# ============================================
# DECISION INTELLIGENCE
# ============================================

decision_engine = DecisionEngine()

decision_output = (

    decision_engine.run(

        state,
        predictions,
        trends
    )
)

# ============================================
# OUTPUT
# ============================================

print("\n")
print("=" * 60)

print("ICTA DECISION INTELLIGENCE")

print("=" * 60)

print("\nPolicy Actions:")

for action in decision_output[
    "policy_actions"
]:

    print(f"   ✓ {action}")

print("\nRecommendations:")

for item in decision_output[
    "recommendations"
]:

    print("\n", item)

print("\nReasoning:")
print(
    decision_output[
        "reasoning"
    ]
)

print("\n")
print("=" * 60)
# Out:
# environment --------
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# All project paths initialized ✅
#
#
# ==================================================
# ICTA PROJECT VALIDATOR
# ==================================================
#
#
# ✅ Domain Registry
# ✅ KPI Registry
# ✅ Signal Registry
# ✅ Dependency Graph
# ✅ Pipeline Registry
# ✅ Domain: traffic
# ✅ Domain: crowd
# ✅ Domain: health
# ✅ Domain: tourism
# ✅ Domain: governance
# ✅ Domain: environment
# ✅ Domain: accommodation
# ✅ Domain: weather
#
#
# ==================================================
#
#
# ============================================================
# PROJECT ROOT REGISTERED ✅
# /content/drive/MyDrive/project_cd
#
#
# Environment initialized Saurabh✅
# ============================================================
#
# Risk forecasting complete ✅
#
# Trend analysis complete ✅
#
# Recommendations generated ✅
#
# AI reasoning complete ✅
#
# Decision intelligence complete ✅
#
#
# ============================================================
# ICTA DECISION INTELLIGENCE
# ============================================================
#
# Policy Actions:
#    ✓ Escalate orchestration
#    ✓ Enable redistribution
#    ✓ Trigger rerouting
#
# Recommendations:
#
#  {'domain': 'traffic', 'recommendation': 'Activate dynamic rerouting', 'priority': 'high', 'timestamp': '2026-05-30 00:04:29.860064'}
#
#  {'domain': 'crowd', 'recommendation': 'Enable crowd redistribution', 'priority': 'high', 'timestamp': '2026-05-30 00:04:29.860085'}
#
#  {'domain': 'health', 'recommendation': 'Increase emergency medical readiness', 'priority': 'medium', 'timestamp': '2026-05-30 00:04:29.860091'}
#
# Reasoning:
# {'observation': 'Accommodation pressure increasing', 'analysis': 'Traffic and crowd pressure likely to rise', 'prediction': [{'forecast': 'traffic_surge', 'probability': 0.85, 'expected_impact': 'high congestion', 'recommended_action': 'preemptive rerouting', 'timestamp': '2026-05-30 00:04:29.853015'}, {'forecast': 'crowd_density_increase', 'probability': 0.78, 'expected_impact': 'queue escalation', 'recommended_action': 'crowd redistribution', 'timestamp': '2026-05-30 00:04:29.853038'}, {'forecast': 'medical_pressure', 'probability': 0.72, 'expected_impact': 'medical queue increase', 'recommended_action': 'increase emergency readiness', 'timestamp': '2026-05-30 00:04:29.853045'}], 'trend_analysis': {'occupancy_trend': 'stable', 'booking_trend': 'normal', 'checkin_trend': 'moderate'}, 'decision': 'Preemptive orchestration recommended', 'timestamp': '2026-05-30 00:04:29.860117'}
#
#
# ============================================================
