# %%
# ============================================
# ENVIRONMENT INITIALIZATION
# ============================================

# %run /content/drive/MyDrive/project_cd/config/environment.py

# ============================================
# IMPORTS
# ============================================

from config.paths import PATHS

from domains.accommodation.modules.ingestion.accommodation_ingestion import (
    AccommodationIngestion
)

# ============================================
# INITIALIZE INGESTION
# ============================================

ingestion = AccommodationIngestion()

# ============================================
# LOAD DATASETS
# ============================================

ingestion.load_booking_logs(

    PATHS["data"]["raw"] +
    "booking_logs.csv"
)

ingestion.load_occupancy_logs(

    PATHS["data"]["raw"] +
    "occupancy_logs.csv"
)

ingestion.load_checkin_logs(

    PATHS["data"]["raw"] +
    "checkin_checkout_logs.csv"
)

# ============================================
# BUILD DATASET
# ============================================

df = ingestion.build_dataset()

# ============================================
# SAVE DATASET
# ============================================

output_path = (

    PATHS["accommodation"]["processed"] +
    "cleaned_accommodation.csv"
)

df.to_csv(
    output_path,
    index=False
)

print("\nAccommodation ingestion complete ✅")
# Out:
# environment --------
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# All project paths initialized ✅
#
#
# ...
# ICTA PROJECT VALIDATOR
# ...
#
#
# ✅ Domain Registry
# ✅ KPI Registry
# ✅ Signal Registry
# ✅ Dependency Graph
# ✅ Pipeline Registry
# ✅ Domain: traffic
# ✅ Domain: crowd
# ✅ Domain: health
# ✅ Domain: tourism
# ✅ Domain: governance
# ✅ Domain: environment
# ✅ Domain: accommodation
# ✅ Domain: weather
#
#
# ...
#
#
# ...
# PROJECT ROOT REGISTERED ✅
# /content/drive/MyDrive/project_cd
#
#
# Environment initialized Saurabh✅
# ...
#
# Booking logs loaded ✅
#
# Occupancy logs loaded ✅
#
# Checkin logs loaded ✅
#
# Accommodation dataset built ✅
#
# Accommodation ingestion complete ✅
