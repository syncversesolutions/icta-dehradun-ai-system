# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# ============================================
# TRAFFIC INGESTION PIPELINE
# ============================================

# ============================================
# ENVIRONMENT
# ============================================

# %run /content/drive/MyDrive/project_cd/config/environment.py

# ============================================
# IMPORTS
# ============================================

from config.paths import PATHS

from domains.traffic.modules.ingestion.traffic_ingestion import (
    ingest_traffic_data
)

# ============================================
# RAW DATA PATHS
# ============================================

checkpoint_path = (

    PATHS["traffic"]["raw"] +
    "checkpoint_logs.csv"
)

crowd_path = (

    PATHS["traffic"]["raw"] +
    "crowd_density_logs.csv"
)

print("\nCheckpoint Path:")
print(checkpoint_path)

print("\nCrowd Path:")
print(crowd_path)

# ============================================
# INGEST DATA
# ============================================

traffic_df = ingest_traffic_data(

    checkpoint_path,
    crowd_path
)

# ============================================
# SAVE CLEANED DATA
# ============================================

output_path = (

    PATHS["traffic"]["processed"] +
    "cleaned_traffic.csv"
)

traffic_df.to_csv(
    output_path,
    index=False
)

# ============================================
# OUTPUT
# ============================================

print(f"\nSaved cleaned data at:")

print(output_path)

print("\nTraffic ingestion complete ✅")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Environment initialized Saurabh✅
# All project paths initialized ✅
#
# Checkpoint Path:
# /content/drive/MyDrive/project_cd/domains/traffic/data/raw/checkpoint_logs.csv
#
# Crowd Path:
# /content/drive/MyDrive/project_cd/domains/traffic/data/raw/crowd_density_logs.csv
#
# Loading raw datasets...
#
# Checkpoint Dataset Columns:
# ['calendar_date', 'route_id', 'checkpoint_name', 'throughput_count', 'congestion_level']
#
# Crowd Dataset Columns:
# ['calendar_date', 'location_id', 'pilgrim_count', 'density_level', 'avg_queue_minutes']
#
# Aligned rows: 60
#
# Final Traffic Dataset Shape:
# (60, 6)
#
# Final Traffic Dataset Columns:
# ['calendar_date', 'route_id', 'checkpoint_name', 'vehicle_count', 'congestion_level', 'crowd_density']
#
# Final Traffic Dataset Sample:
#   calendar_date route_id        checkpoint_name  vehicle_count  \
# ...
