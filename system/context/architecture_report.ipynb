# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys

sys.path.append(
    "/content/drive/MyDrive/project_cd"
)

from system.context.architecture_report import (
    ArchitectureReport
)

report = ArchitectureReport()

report.run()
# Out:
# All project paths initialized ✅
#
#
# ...
# ICTA ARCHITECTURE REPORT
# ...
#
#
# ...
# DOMAIN STATUS
# ...
#
# Domain: traffic
# Status: active
# Dashboard Visible: True
#
# Domain: crowd
# Status: under_development
# Dashboard Visible: False
#
# Domain: health
# Status: planned
# Dashboard Visible: False
#
# Domain: tourism
# Status: planned
# Dashboard Visible: False
#
# Domain: governance
# Status: planned
# Dashboard Visible: False
#
# Domain: environment
# Status: planned
# Dashboard Visible: False
#
# Domain: accommodation
# Status: future
# Dashboard Visible: False
#
# Domain: weather
# Status: future
# Dashboard Visible: False
#
#
# ...
# KPI STATUS
# ...
# traffic: 5 KPIs
#
# Total KPIs: 5
#
#
# ...
# SIGNAL STATUS
# ...
# traffic: 4 signals
#
# Total Signals: 4
#
#
# ...
# DEPENDENCY GRAPH
# ...
# traffic.congestion_score -> 3 dependencies
#    ↳ crowd.crowd_density
#    ↳ health.medical_incidents
#    ↳ tourism.route_efficiency
# traffic.predicted_risk_level -> 3 dependencies
#    ↳ system.alert_level
# ...
