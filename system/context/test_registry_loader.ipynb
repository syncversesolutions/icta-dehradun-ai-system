# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
from pathlib import Path

# Add the project directory to the system path
PROJECT_ROOT = "/content/drive/MyDrive/project_cd"
sys.path.append(PROJECT_ROOT)

# Import the fixed RegistryLoader from your project files
from system.context.registry_loader import RegistryLoader

loader = RegistryLoader()

print(loader.load_domains())
print(loader.load_dependency_graph())
# Out:
# All project paths initialized ✅
# {'version': '1.0', 'active_domains': ['traffic'], 'planned_domains': ['crowd', 'health', 'tourism', 'governance', 'environment'], 'future_domains': ['accommodation', 'transport', 'weather', 'medical', 'economy', 'disaster']}
# {'traffic': {'congestion_score': {'affects': ['crowd_management', 'emergency_response', 'route_efficiency']}, 'predicted_risk_level': {'affects': ['alert_system', 'traffic_rerouting', 'public_safety']}}, 'crowd': {'crowd_density': {'affects': ['traffic_flow', 'pilgrim_safety', 'queue_management']}}, 'health': {'medical_incidents': {'affects': ['emergency_services', 'hospital_capacity']}}}
