# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# ============================================
# ENVIRONMENT INITIALIZATION
# ============================================

# %run /content/drive/MyDrive/project_cd/config/environment.py

# ============================================
# IMPORTS
# ============================================

from system.orchestration.impact_engine import (
    ImpactEngine
)

# ============================================
# INITIALIZE ENGINE
# ============================================

engine = ImpactEngine()

# ============================================
# TEST SIGNAL
# ============================================

signal_node = (
    "accommodation.occupancy_rate"
)

# ============================================
# RUN ANALYSIS
# ============================================

analysis = engine.analyze_signal(
    signal_node
)

# ============================================
# DISPLAY RESULTS
# ============================================

engine.display_analysis(
    analysis
)
# Out:
# environment --------
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# All project paths initialized ✅
#
#
# ==================================================
# ICTA PROJECT VALIDATOR
# ==================================================
#
#
# ✅ Domain Registry
# ✅ KPI Registry
# ✅ Signal Registry
# ✅ Dependency Graph
# ✅ Pipeline Registry
# ✅ Domain: traffic
# ✅ Domain: crowd
# ✅ Domain: health
# ✅ Domain: tourism
# ✅ Domain: governance
# ✅ Domain: environment
# ✅ Domain: accommodation
# ✅ Domain: weather
#
#
# ==================================================
#
#
# ============================================================
# PROJECT ROOT REGISTERED ✅
# /content/drive/MyDrive/project_cd
#
#
# Environment initialized Saurabh✅
# ============================================================
#
# Dependency graph loaded ✅
#
# Node not found: system.alert_level
#
# Node not found: governance.emergency_response
#
# Node not found: tourism.queue_delay
#
# Node not found: tourism.route_efficiency
#
# Node not found: tourism.local_revenue
#
#
# ============================================================
# IMPACT ANALYSIS REPORT
# ============================================================
#
# Source Signal:
# accommodation.occupancy_rate
#
# Affected Domains:
# ['governance', 'crowd', 'traffic', 'health', 'system', 'tourism']
#
# Risk Level:
# high
#
# Affected Nodes:
#    ↳ tourism.route_efficiency
#    ↳ crowd.crowd_density
#    ↳ health.medical_incidents
#    ↳ tourism.queue_delay
#    ↳ traffic.congestion_score
#    ↳ governance.emergency_response
#    ↳ system.alert_level
#    ↳ tourism.local_revenue
#
# Total Impacts:
# 8
#
#
# ============================================================
